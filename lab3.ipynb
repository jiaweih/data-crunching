# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('TradeoffData.csv')
df.head(20)
# Out:
#    Group Treatment  Replicate  RelativeFitness
# 0    BKB      Tube          1         0.869963
# 1    BKB      Tube          2         1.000363
# 2    BKB      Tube          3         0.982935
# 3    BAC      Tube          1         0.810392
# 4    BAC      Tube          2         0.795107
# 5    JDK      Tube          1         0.849204
# 6    JDK      Tube          2         0.917637
# 7    JDK      Tube          3         0.905323
# 8    ETH      Tube          1         0.930821
# 9    ETH      Tube          2         0.958183
# 10   ETH      Tube          3         0.914288
# 11   SWI      Tube          1         0.918514
# 12   SWI      Tube          2         0.909023
# 13   SWI      Tube          3         0.928405
# 14   PPP      Tube          1         0.990500
# 15   PPP      Tube          2         0.971565
# 16   PPP      Tube          3         0.948767
# 17   ECO      Tube          1         0.996871
# 18   ECO      Tube          2         0.976750
# ...

# %%
df.Group.value_counts()
# Out:
# FIT    6
# ETH    6
# DOS    6
# ECO    6
# JDK    6
# BKB    6
# HHE    6
# PPP    6
# H2W    6
# SWI    6
# BAC    4
# dtype: int64

# %%
df_by_treat = df.groupby('Treatment')
# Out:
#    Group Treatment  Replicate  RelativeFitness
# 0    BKB      Tube          1         0.869963
# 1    BKB      Tube          2         1.000363
# 2    BKB      Tube          3         0.982935
# 3    BAC      Tube          1         0.810392
# 4    BAC      Tube          2         0.795107
# 5    JDK      Tube          1         0.849204
# 6    JDK      Tube          2         0.917637
# 7    JDK      Tube          3         0.905323
# 8    ETH      Tube          1         0.930821
# 9    ETH      Tube          2         0.958183
# 32   BKB      Dish          1         1.152544
# 33   BKB      Dish          2         1.287085
# 34   BKB      Dish          3         1.507415
# 35   BAC      Dish          2         1.652234
# 36   BAC      Dish          3         1.615022
# 37   JDK      Dish          1         1.510268
# 38   JDK      Dish          2         1.582701
# 39   JDK      Dish          3         1.547152
# 40   ETH      Dish          1         1.612816
# ...

# %%
pd.crosstab(df.Replicate,df.RelativeFitness)
# Out:
# RelativeFitness  0.795107  0.810392  0.849204  0.853906  0.869963  0.905323  \
# Replicate
# 1                       0         1         1         0         1         0
# 2                       1         0         0         1         0         0
# 3                       0         0         0         0         0         1
#
# RelativeFitness  0.909023  0.914288  0.915304  0.917637    ...     1.553568  \
# Replicate                                                  ...
# 1                       0         0         1         0    ...            0
# 2                       1         0         0         1    ...            0
# 3                       0         1         0         0    ...            1
#
# RelativeFitness  1.581325  1.581386  1.582701  1.585587  1.594531  1.612816  \
# Replicate
# 1                       0         0         0         0         1         1
# 2                       1         1         1         0         0         0
# ...

# %%
df_by_treat.RelativeFitness.describe()
# Out:
# Treatment
# Dish       count    32.000000
#            mean      1.456359
#            std       0.184792
#            min       0.955221
#            25%       1.429005
#            50%       1.510884
#            75%       1.581340
#            max       1.699276
# Tube       count    32.000000
#            mean      0.929589
#            std       0.050153
#            min       0.795107
#            25%       0.915050
#            50%       0.939089
#            75%       0.953505
#            max       1.000363
# dtype: float64

# %%
df_by_treat.aggregate(np.sum)
# Out:
#            Replicate  RelativeFitness
# Treatment
# Dish              65        46.603473
# Tube              63        29.746859

# %%
df.groupby('Treatment').agg({'RelativeFitness':[np.size,np.sum]})
# Out:
#            RelativeFitness
#                       size        sum
# Treatment
# Dish                    32  46.603473
# Tube                    32  29.746859

# %%
df_by_treat.sum()
# Out:
#            Replicate  RelativeFitness
# Treatment
# Dish              65        46.603473
# Tube              63        29.746859

# %%
df_by_groupytreatment = df.groupby(['Group','Treatment'])

# %%
df_by_groupytreatment.describe().head(20)
# Out:
#                        Replicate  RelativeFitness
# Group Treatment
# BAC   Dish      count   2.000000         2.000000
#                 mean    2.500000         1.633628
#                 std     0.707107         0.026313
#                 min     2.000000         1.615022
#                 25%     2.250000         1.624325
#                 50%     2.500000         1.633628
#                 75%     2.750000         1.642931
#                 max     3.000000         1.652234
#       Tube      count   2.000000         2.000000
#                 mean    1.500000         0.802749
#                 std     0.707107         0.010808
#                 min     1.000000         0.795107
#                 25%     1.250000         0.798928
#                 50%     1.500000         0.802749
#                 75%     1.750000         0.806570
#                 max     2.000000         0.810392
# BKB   Dish      count   3.000000         3.000000
# ...

# %%
df_by_groupytreatment.aggregate(np.sum)
# Out:
#                  Replicate  RelativeFitness
# Group Treatment
# BAC   Dish               5         3.267256
#       Tube               3         1.605498
# BKB   Dish               6         3.947045
#       Tube               6         2.853261
# DOS   Dish               6         4.761443
#       Tube               6         2.836784
# ECO   Dish               6         4.683590
#       Tube               6         2.913100
# ETH   Dish               6         4.448824
#       Tube               6         2.803292
# FIT   Dish               6         3.005880
#       Tube               6         2.869231
# H2W   Dish               6         4.575683
#       Tube               6         2.707909
# HHE   Dish               6         4.274319
#       Tube               6         2.818846
# JDK   Dish               6         4.640121
#       Tube               6         2.672164
# PPP   Dish               6         4.643923
#       Tube               6         2.910832
# ...

# %%
df_by_groupytreatment.agg([np.sum,np.mean])
# Out:
#                  Replicate        RelativeFitness
#                        sum  mean              sum      mean
# Group Treatment
# BAC   Dish               5   2.5         3.267256  1.633628
#       Tube               3   1.5         1.605498  0.802749
# BKB   Dish               6   2.0         3.947045  1.315682
#       Tube               6   2.0         2.853261  0.951087
# DOS   Dish               6   2.0         4.761443  1.587148
#       Tube               6   2.0         2.836784  0.945595
# ECO   Dish               6   2.0         4.683590  1.561197
#       Tube               6   2.0         2.913100  0.971033
# ETH   Dish               6   2.0         4.448824  1.482941
#       Tube               6   2.0         2.803292  0.934431
# FIT   Dish               6   2.0         3.005880  1.001960
#       Tube               6   2.0         2.869231  0.956410
# H2W   Dish               6   2.0         4.575683  1.525228
#       Tube               6   2.0         2.707909  0.902636
# ...

# %%
# %matplotlib inline
import scipy.stats as stats
import matplotlib.pyplot as plt
mu = 0.
sigma = 1.
samples = np.random.normal(mu,sigma,10000)
plt.hist(samples,bins=25,normed=True)
plt.hist(stats.norm().rvs(size=10000),bins=25,alpha=.5,normed=True)
x = np.linspace(-4,4,100)
plt.plot(x,stats.norm().pdf(x))
plt.plot(x,stats.norm().cdf(x))

# %%
keys = ['a','b','c']
values = [1,2,3]
dic = {k:v for k,v in zip(keys,values)}
dic

# %%
u_cols = ['user_id', 'age', 'sex', 'occupation', 'zip_code']
users = pd.read_csv('ml-100k/u.user', sep='|', names=u_cols)

r_cols = ['user_id', 'movie_id', 'rating', 'unix_timestamp']
ratings = pd.read_csv('ml-100k/u.data', sep='|', names=r_cols)

# let's only load the first five columns of the file with usecols
m_cols = ['movie_id', 'title', 'release_date', 'video_release_date', 'imdb_url']
movies = pd.read_csv('ml-100k/u.item', sep='|', names=m_cols, usecols=range(5))

# %%
movies.head(10)
# Out:
#    movie_id                                              title release_date  \
# 0         1                                   Toy Story (1995)  01-Jan-1995
# 1         2                                   GoldenEye (1995)  01-Jan-1995
# 2         3                                  Four Rooms (1995)  01-Jan-1995
# 3         4                                  Get Shorty (1995)  01-Jan-1995
# 4         5                                     Copycat (1995)  01-Jan-1995
# 5         6  Shanghai Triad (Yao a yao yao dao waipo qiao) ...  01-Jan-1995
# 6         7                              Twelve Monkeys (1995)  01-Jan-1995
# 7         8                                        Babe (1995)  01-Jan-1995
# 8         9                            Dead Man Walking (1995)  01-Jan-1995
# 9        10                                 Richard III (1995)  22-Jan-1996
#
#    video_release_date                                           imdb_url
# ...

# %%
users.describe()
# Out:
#           user_id         age
# count  943.000000  943.000000
# mean   472.000000   34.051962
# std    272.364951   12.192740
# min      1.000000    7.000000
# 25%    236.500000   25.000000
# 50%    472.000000   31.000000
# 75%    707.500000   43.000000
# max    943.000000   73.000000

# %%
users[users.age>25].head()
# Out:
#    user_id  age sex     occupation zip_code
# 1        2   53   F          other    94043
# 4        5   33   F          other    15213
# 5        6   42   M      executive    98101
# 6        7   57   M  administrator    91344
# 7        8   36   M  administrator    05201

# %%
users[(users.age == 40) & (users.sex == 'F')].head()
# Out:
#      user_id  age sex occupation zip_code
# 26        27   40   F  librarian    30030
# 146      147   40   F  librarian    02143
# 259      260   40   F     artist    89801
# 503      504   40   F     writer    92115
# 597      598   40   F  marketing    43085

# %%
users.set_index('user_id',inplace=True)
users.head()
# Out:
#          age sex  occupation zip_code
# user_id
# 1         24   M  technician    85711
# 2         53   F       other    94043
# 3         23   M      writer    32067
# 4         24   M  technician    43537
# 5         33   F       other    15213

# %%
headers = ['name', 'title', 'department', 'salary']
url = 'https://raw.githubusercontent.com/gjreda/gregreda.com/master/content/notebooks/data/city-of-chicago-salaries.csv'
chicago = pd.read_csv(url,
                      header=False,
                      names=headers,
                      converters={'salary': lambda x: float(x.replace('$', ''))})

# %%
chicago.head()
# Out:
#                     name                     title        department  salary
# 0        AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT   85512
# 1      AARON,  JEFFERY M            POLICE OFFICER            POLICE   75372
# 2    AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES   80916
# 3    ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT   99648
# 4  ABBATACOLA,  ROBERT J       ELECTRICAL MECHANIC          AVIATION   89440

# %%
by_dept = chicago.groupby('department')
# Out:
#                                name  \
# 0                   AARON,  ELVIA J
# 1                 AARON,  JEFFERY M
# 2               AARON,  KIMBERLEI R
# 3               ABAD JR,  VICENTE M
# 4             ABBATACOLA,  ROBERT J
# 5             ABBATEMARCO,  JAMES J
# 6                  ABBATE,  TERRY M
# 7                  ABBOTT,  BETTY L
# 8                 ABBOTT,  LYNISE M
# 9            ABBRUZZESE,  WILLIAM J
# 10                  ABDALLAH,  ZAID
# 11            ABDELHADI,  ABDALMAHD
# 12              ABDELLATIF,  AREF R
# 14               ABDELQAWI,  YOSEPH
# 15              ABDOLLAHZADEH,  ALI
# 16         ABDUL-KARIM,  MUHAMMAD A
# 17                 ABDULLAH,  ASKIA
# 18              ABDULLAH,  DANIEL N
# 19                 ABDULLAH,  KEVIN
# 21              ABDULLAH,  RASHAD J
# 23                ABELS,  KENNETH L
# 24            ABERCROMBIE,  TIMOTHY
# 25           ABOUELKHEIR,  HASSAN A
# 26               ABRAHAM,  GIRLEY T
# 27               ABRAHAM,  GODWIN K
# ...

# %%
# NOT NULL records within each column
by_dept.count().head()
# Out:
#                    name  title  salary
# department
# ADMIN HEARNG         42     42      42
# ANIMAL CONTRL        61     61      61
# AVIATION           1218   1218    1218
# BOARD OF ELECTION   110    110     110
# BOARD OF ETHICS       9      9       9

# %%
by_dept.size().head()
# Out:
# department
# ADMIN HEARNG           42
# ANIMAL CONTRL          61
# AVIATION             1218
# BOARD OF ELECTION     110
# BOARD OF ETHICS         9
# dtype: int64

# %%
by_dept.mean()[20:25]
# Out:
#                          salary
# department
# HUMAN RESOURCES    71337.176471
# INSPECTOR GEN      80703.000000
# IPRA               82425.035294
# LAW                70853.156000
# LICENSE APPL COMM  65436.000000

# %%
by_dept.median()[20:25]
# Out:
#                    salary
# department
# HUMAN RESOURCES     68496
# INSPECTOR GEN       76116
# IPRA                82524
# LAW                 66492
# LICENSE APPL COMM   65436

# %%
by_dept.title.unique()
# Out:
# department
# ADMIN HEARNG             [STAFF ASSISTANT - EXCLUDED, ADMINISTRATIVE AS...
# ANIMAL CONTRL            [ANIMAL CARE AIDE I, ANIMAL CONTROL OFFICER, E...
# AVIATION                 [ELECTRICAL MECHANIC, AVIATION SECURITY OFFICE...
# BOARD OF ELECTION        [SENIOR CLERK-ELECTIONS, PRINCIPAL CLERK-ELECT...
# BOARD OF ETHICS          [EXECUTIVE DIR - BOARD OF ETHICS, STAFF ASST, ...
# BUDGET & MGMT            [DIR OF PUBLIC INFORMATION, SENIOR BUDGET ANAL...
# BUILDINGS                [PLUMBING INSPECTOR, VENTILATION AND FURNACE I...
# BUSINESS AFFAIRS         [ENGINEERING TECHNICIAN V, SENIOR PUBLIC INFOR...
# CITY CLERK               [EDITORIAL ASST, ASST MANAGING EDITOR COUNCIL ...
# CITY COUNCIL             [LEGISLATIVE AIDE, ASST TO THE ALDERMAN, ALDER...
# COMMUNITY DEVELOPMENT    [ACCOUNTING TECHNICIAN II, SENIOR RESEARCH ANA...
# CULTURAL AFFAIRS         [SPECIAL EVENTS COORD III, STUDENT INTERN, ASS...
# ...

# %%
#Return number of unique elements in the object.
by_dept.title.nunique().order(ascending=False)
# Out:
# department
# WATER MGMNT              153
# TRANSPORTN               150
# POLICE                   130
# AVIATION                 125
# HEALTH                   118
# GENERAL SERVICES         117
# FAMILY & SUPPORT         113
# FINANCE                   98
# FIRE                      91
# PUBLIC LIBRARY            72
# STREETS & SAN             71
# COMMUNITY DEVELOPMENT     71
# OEMC                      69
# BUSINESS AFFAIRS          64
# LAW                       50
# BUILDINGS                 49
# DoIT                      40
# CULTURAL AFFAIRS          39
# CITY CLERK                39
# HUMAN RESOURCES           32
# PROCUREMENT               30
# CITY COUNCIL              28
# MAYOR'S OFFICE            28
# BUDGET & MGMT             24
# BOARD OF ELECTION         23
# INSPECTOR GEN             23
# DISABILITIES              22
# IPRA                      22
# ANIMAL CONTRL             19
# TREASURER                 16
# ADMIN HEARNG              15
# ...

# %%
def ranker(df):
    """Assigns a rank to each employee based on salary, with 1 being the highest paid.
    Assumes the data is DESC sorted."""
    df['dept_rank'] = np.arange(len(df)) + 1
    return df
chicago.sort('salary', ascending=False, inplace=True)
chicago = chicago.groupby('department').apply(ranker)
print chicago[chicago.dept_rank == 1].head(7)
# Out:
#                          name                     title      department  \
# 18039     MC CARTHY,  GARRY F  SUPERINTENDENT OF POLICE          POLICE
# 8004           EMANUEL,  RAHM                     MAYOR  MAYOR'S OFFICE
# 25588       SANTIAGO,  JOSE A         FIRE COMMISSIONER            FIRE
# 763    ANDOLINO,  ROSEMARIE S  COMMISSIONER OF AVIATION        AVIATION
# 4697     CHOUCAIR,  BECHARA N    COMMISSIONER OF HEALTH          HEALTH
# 21971      PATTON,  STEPHEN R       CORPORATION COUNSEL             LAW
# 12635      HOLT,  ALEXANDRA D                BUDGET DIR   BUDGET & MGMT
#
#        salary  dept_rank
# 18039  260004          1
# 8004   216210          1
# 25588  202728          1
# 763    186576          1
# 4697   177156          1
# 21971  173664          1
# 12635  169992          1

# %%
chicago[chicago.department == "LAW"][:5]
# Out:
#                        name                           title department  \
# 21971    PATTON,  STEPHEN R             CORPORATION COUNSEL        LAW
# 6311     DARLING,  LESLIE M  FIRST ASST CORPORATION COUNSEL        LAW
# 17680  MARTINICO,  JOSEPH P          CHIEF LABOR NEGOTIATOR        LAW
# 22357      PETERS,  LYNDA A                 CITY PROSECUTOR        LAW
# 31383    WONG JR,  EDWARD J      DEPUTY CORPORATION COUNSEL        LAW
#
#        salary  dept_rank
# 21971  173664          1
# 6311   149160          2
# 17680  144036          3
# 22357  139932          4
# 31383  137076          5

# %%
chicago[:20]
# Out:
#                          name                            title  \
# 18039     MC CARTHY,  GARRY F         SUPERINTENDENT OF POLICE
# 8004           EMANUEL,  RAHM                            MAYOR
# 25588       SANTIAGO,  JOSE A                FIRE COMMISSIONER
# 27594   STEWART III,  CHARLES   FIRST DEPUTY FIRE COMMISSIONER
# 31587      WYSINGER,  ALFONZA      FIRST DEPUTY SUPERINTENDENT
# 763    ANDOLINO,  ROSEMARIE S         COMMISSIONER OF AVIATION
# 19175  MINIOTIS,  CONSTANTINE  SUPERINTENDENT'S CHIEF OF STAFF
# 28955        TRACY,  ROBERT J                            CHIEF
# 3733     CALLAHAN,  MICHAEL E         DEPUTY FIRE COMMISSIONER
# 8982      FORD II,  RICHARD C         DEPUTY FIRE COMMISSIONER
# 18604      MC NICHOLAS,  JOHN         DEPUTY FIRE COMMISSIONER
# 29512     VASQUEZ,  ANTHONY P         DEPUTY FIRE COMMISSIONER
# 4697     CHOUCAIR,  BECHARA N           COMMISSIONER OF HEALTH
# 24921       ROTI,  NICHOLAS J                            CHIEF
# ...
